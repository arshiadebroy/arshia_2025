# %% [markdown]
# ---
# layout: post
# title: Teaching Data Science Blog
# description: Reflection and Information of Final Project
# courses: { csp: {week:1} }
# comments: true
# sticky_rank: 1
# ---

# %% [markdown]
# ## Overall Breakdown
#
# 1. Surviving Sickness
# 2. Travel Recommender
# 3. College Predictor
# 4. AI Pet
# 5. Score Predictor
# 6. Titanic
# 7. Facial Recognition
#
# <h2> Step by Step </h2>
#
#
# <h3> 1. Surviving Sickness </h3>
#
# _-What?:_
# This is a feature that takes the qualities (Age and Sex) and the symptoms (Fever, Cough, Shortness of Breath, Chest Pain) of users and predicts survival. This was made using information in the Influenza symptoms and death cases. This is the **simplest feature** we have on our website since it was made **DIRECTLY** from the Titanic model provided; it just tweaked the data set and input options. This teaches users how to set up basic containers and input boxes. Yes/no intake for symptoms also requires less backend and frontend code, which makes it easier for users to understand the basic foundations of using machine learning in data science.
#
# _-Model:_
# Uses a **Logistic Regression**. This works with binary classification and can predict outputs when users input simple yes/no or true/false data. Since this is a disease tracking feature, yes/no questions can be used to ask if users are feeling a certain symptom, allowing the model to accurately predict survivability.
#
# _-Data Formats:_
# Uses **text and numeric data formatting**. The numeric data is used to input user age, and the text is what allows users to input either yes/no, depending on their symptoms. The output is also given in a textual format.
#
# _-Different Use Cases:_
# This feature can be used in **healthcare and education**. Since this is a disease survivability tracker, it has the potential to be adapted into a survey that patients can take to diagnose themselves with different diseases and their survivability. However, since this can be very risky, it is more applicable in an educational setting. This data is based on previous cases of diseases, so it can be used by medical students to study how different variables like age/ other symptoms affect survivability.
#
# _-Pipeline Stages:_
# (link to the documentation blog will go here)
#
# _-Tooling/Libraries:_
# This user inputs programs from **scikit-learn** (LogisticRegression and LabelEncoder) and **Pandas**. It was not done in Jupyter notebooks, and it has a **full Python** backend and JavaScript frontend. This feature also utilizes a CSV file, where the data that's being analyzed is stored.
#
# _-Data Source Type:_
# The data stored in the CSV file was taken from an **open-source dataset** created by UC Irvine.  [Link Here](https://archive.ics.uci.edu/dataset/861/influenza+outbreak+event+prediction+via+twitter)
#
# <img width="278" alt="Image" src="https://github.com/user-attachments/assets/2f5db6bd-f729-4a61-a410-377d1486eb3e" />
#
#
# <br>
#
# <h1>   </h1>
#
# <h3>2. Travel </h3>
#
# _-What?:_
# This takes pre-made inputs from a dropdown menu concerning the season (summer, winter, spring, fall), activity (relax, beach, hike, etc), budget (high, low, medium), and continent. It then outputs a specific country that suits the user's expectations. This was placed after the sickness model in difficulty, as it includes multiple drop-down menus that require more coding in both the frontend and backend. Data must be carefully crafted/found to satisfy each category, which can be harder to do. This is a slight step above the basic foundational Sickness Survivability.
#
# _-Model:_
# Uses a **Decision Tree Classifier**. This works by traveling through a tree-like dataset (If the user likes summer, THEN it will travel down that branch of the tree). Since there are multiple options in the dropdown frontend container, this is the best model to use.
#
# _-Data Formats:_
# Pure text formatting.
#
# _-Different Use Cases:_
# This feature can be used loosely for social good. It has the potential to help people choose their next vacation. However, since that is not likely, it can easily be adapted to any other use while maintaining the overall structure, as it still uses data science and analysis.
#
# _-Pipeline Stages:_
# (link to the documentation blog will go here)
#
# _-Tooling/Libraries:_
# This user inputs programs from **scikit-learn** (DecisionTreeClassifier, LabelEncoder) and **numpy**. It was not done in Jupyter notebooks, and it has a **full Python** backend and JavaScript frontend.
#
# _-Data Source Type:_
# The data was self-crafted. In the future, it will be better to use open-source data since self-crafted data is very limited in its use. All 195 countries cannot be self-added.
#
# <img width="226" alt="Image" src="https://github.com/user-attachments/assets/c178893e-1515-45e1-b7fc-4b7956672101" />
#
# <h1>  </h1>
#
# <h3>3. College Predictor</h3>
#
# _-What?:_
# This takes inputs like GPA, SAT score, ACT score, AP class count, and extracurriculars to provide a UC that would best fit the user, as well as the user's predicted acceptance chance percentage. This was placed after the previous two features in terms of difficulty because of how it gives **two different types of outputs**. Prior to this, the output was either pure numerical or textual, but this shows how you can combine both. Because of the data analyzed in the backend, the frontend predicts which of the colleges best suits the percentage acceptance that is sent over through the API endpoint, and both the college and percentage are displayed. This further shows frontend/backend integration with data science.
#
# _-Model:_
# Uses a **Decision Tree Classifier** and **Linear Regression**.  Since there are multiple inputs that can be given for things like SAT/ACT scores and etc, this is the best model to use.
#
# _-Data Formats:_
# Pure numerical formatting. College stats generally tend to be numbers, so this was the best fit.
#
# _-Different Use Cases:_
# This feature can be used for education. By playing around with the different stats, users can observe which test scores/GPA/extracurriculars are most important for higher acceptances. This will be useful for many high school students looking to get into a UC.
#
# _-Pipeline Stages:_
# (link to the documentation blog will go here)
#
# _-Tooling/Libraries:_
# This user inputs programs from **scikit-learn** (DecisionTreeClassifier, LinearRegression), **pandas**, and **numpy**. It was not done in Jupyter notebooks, and it has a **full Python** backend and JavaScript frontend.
#
# _-Data Source Type:_
# The data was simulated based on UC acceptance stats/ information. [Link Here](https://www.universityofcalifornia.edu/about-us/information-center/admissions-source-school)
#
# <img width="512" alt="Image" src="https://github.com/user-attachments/assets/b4cd4459-2ca7-4e4c-ace5-60f2eb1bd2b8" />
#
# <h1>   </h1>
#
# <h3>4. AI Pet</h3>
#
# _-What?:_
# This takes inputs on a number scale of 1-5 on things like how much food users give to a pet, how much users play with the pet, and how much sleep the pet gets. Based on these numbers, the model will predict the pet's happiness on a scale of 1-10 and display a progress bar with animation, change the image of the pet's facial expression, and display a speech bubble based on the pet's thoughts. This was placed after the previous features because not only does it have multiple outputs, it also has **different output formatting** (image, animation, and text). All of these outputs are based on the data analysis happiness result, which shows users how data science results can be used to display various types of outputs, not just pure text.
#
# _-Model:_
# Uses a **Decision Tree Classifier** and **Linear Regression** like previous features.
#
# _-Data Formats:_
# Pure numerical formatting. (scale from 1-5 as mentioned above).
#
# _-Different Use Cases:_
# This feature can be used loosely for social good as it provides entertaining/ engaging features. Other than making a user laugh, this feature does not have much of a technical or "sellable" use.
#
# _-Pipeline Stages:_
# (link to the documentation blog will go here)
#
# _-Tooling/Libraries:_
# This user inputs programs from **scikit-learn** (DecisionTreeClassifier, LinearRegression), **pandas**, and **numpy**. It was not done in Jupyter notebooks, and it has a **full Python** backend and JavaScript frontend.
#
# _-Data Source Type:_
# The data for this was **self-created**. Since the input can only take 5 numbers, it was easy to craft. It was also easier to train the program using a few self-made data points.
#
# <img width="580" alt="Image" src="https://github.com/user-attachments/assets/e4102fcb-b516-4145-9f98-dc53c0eb0080" />
#
# <h1>    </h1>
#
# <h3>5. Score Predictor</h3>
#
# _-What?:_
# This uses a slider bar and asks for the user's test score (MCQ and FRQ). Based on the data inputted, a graph will be displayed showing the user's score compared to other test takers as well as the predicted score result. The graph is not something that is static, but users can physically see it move/ change as they adjust the slider bar. Since this feature introduces how to **categorize and organize analyzed data in a graph structure**, this is considerably more difficult than previous features. The purpose of data science is to analyze data, and graphs are a huge part of that. This feature can teach users how to utilize graphs while maintaining simple textual outputs (the actual score itself).
#
# _-Model:_
# Uses a **Quantile Transformer**. This takes data and spreads it out into the graph that we see. It converts the raw test scores that users input into a percentage that can be used to compare scores with other test-takers and display them in a graph format.
#
# _-Data Formats:_
# Numerical (you can manually input test scores) and the slider bar.
#
# _-Different Use Cases:_
# This feature can be used for education, as test score predictors and test comparisons are usually only used in educational settings. Students are always wondering about their test scores and performance, so this feature can be helpful.
#
# _-Pipeline Stages:_
# (link to the documentation blog will go here)
#
# _-Tooling/Libraries:_
# This user inputs programs from **scikit-learn** (QuantileTransformer),  **numpy**, and **pandas**. It was not done in Jupyter notebooks, and it has a **full Python** backend and JavaScript frontend. It also utilizes a CSV file, where the previous test score data is stored.
#
# _-Data Source Type:_
# The data was a mix of crowdsourced and self-created. Since specific test scores are not publicly released, much of the data was crafted by using self-submitted surveys that have previous AP scores and results.
#
# <img width="528" alt="Image" src="https://github.com/user-attachments/assets/8f400849-80d7-4c69-b624-8848856b4710" />
#
# <h1>   </h1>
#
# <h3>6. Titanic</h3>
#
# _-What?:_
# This takes user information (name, sex, age) and fictional information like passenger class, place of embarkation, siblings onboard, etc. It then predicts whether you will survive the Titanic or not. There is an option for users to publicly store their results, in which case the result is stored permanently on the website and allows others to view it. There is also a pie chart that is freshly created based on the predicted Titanic survivability score. This is by far the most impressive feature out of all the member created ones since it not only has multiple input options (like Surivability and movie), multiple types of outputs (like the Pet), a graph/ data display of some sort (like the score predictor), but it also can store the data predicted through the backend. This adds an extra layer to how data science can be used and displayed.
#
# _-Model:_
# Uses a **Decision Tree Classifier**,  **Linear Regression**,  and **One Hot Encoder**.
#
# _-Data Formats:_
# A mix of numerical and text. Text input is for the user's name, while the numerical input is used for things like the number of siblings, class, etc.
#
# _-Different Use Cases:_
# This feature can be used loosely for education as it is a fun and interactive way to learn about the historical Titanic crash. Students/ users can learn how different things like money, gender, and family information affected how people survived back then.
#
# _-Pipeline Stages:_
# (link to the documentation blog will go here)
#
# _-Tooling/Libraries:_
# This user inputs programs from **scikit-learn** (DecisionTreeClassifier, LinearRegression, OneHotEncoder), **pandas**, **numpy**, and **seaborn**. It was not done in Jupyter notebooks, and it has a **full Python** backend and JavaScript frontend.
#
# _-Data Source Type:_
# The data for this was taken from an **API**. (I believe, need to double check this with Alex).
#
# <img width="368" alt="Image" src="https://github.com/user-attachments/assets/00b577af-a293-4e6b-b011-cd9236b4fc9e" />

# %% [markdown]
# ##  Personal Model Breakdown: Surviving Sickness
# Have you ever wondered what your chances are of surviving a nasty case of influenza? In this project, we set out to answer that question using data science and machine learning. Our model doesn’t just guess — it makes predictions based on real-world data and statistical analysis. Let’s break down how it works.
#
# ##  The Big Idea
# The goal was to build a tool that could predict the probability of surviving influenza based on key symptoms and patient information. Using a logistic regression model trained on historical health data, we can now estimate someone’s survival odds with just a few inputs.

# %% [markdown]
# -Data Formats:_
# Uses **text and numeric data formatting**. The numeric data is used to input user age, and the text is what allows users to input either yes/no, depending on their symptoms. The output is also given in a textual format.
#
# _-Different Use Cases:_
# This feature can be used in **healthcare and education**. Since this is a disease survivability tracker, it has the potential to be adapted into a survey that patients can take to diagnose themselves with different diseases and their survivability. However, since this can be very risky, it is more applicable in an educational setting. This data is based on previous cases of diseases, so it can be used by medical students to study how different variables like age/ other symptoms affect survivability.
#
#
# _-Tooling/Libraries:_
# This user inputs programs from **scikit-learn** (LogisticRegression and LabelEncoder) and **Pandas**. It was not done in Jupyter notebooks, and it has a **full Python** backend and JavaScript frontend. This feature also utilizes a CSV file, where the data that's being analyzed is stored.
#
# _-Data Source Type:_
# The data stored in the CSV file was taken from an **open-source dataset** created by UC Irvine.  [Link Here](https://archive.ics.uci.edu/dataset/861/influenza+outbreak+event+prediction+via+twitter)

# %% [markdown]
# ##  The Data
# We used a dataset that contains anonymized health records of people who had influenza.The dataset was from a reputable source, which is UCI data repository. Each row in the dataset represents a patient, and each column represents a symptom or factor:
#
# | Feature               | Description                                 |
# |------------------------|---------------------------------------------|
# | Age                   | Patient’s age in years                      |
# | Fever                 | Did the patient have a fever? (Yes/No)      |
# | Cough                 | Was a cough present? (Yes/No)               |
# | Shortness of Breath   | Difficulty breathing? (Yes/No)              |
# | Survived              | Outcome (1 = survived, 0 = did not survive) |

# %% [markdown]
# ##  Future Improvements
# While our current model is functional, there's always room to grow:
#
#  Add more features like sex, vaccination status, or comorbidities
#
# Visualize the output with graphs or survival curves
#
# Try more complex models (Random Forests, Gradient Boosting)
#
# This project is just the beginning — it shows how machine learning can support healthcare decisions by giving people insight into their conditions.
#
# | Aspect              | Detail                                 |
# |---------------------|----------------------------------------|
# | ML Model            | Logistic Regression                    |
# | Prediction Goal     | Probability of surviving influenza     |
# | Inputs Used         | Age, Fever, Cough, Shortness of Breath |
# | Tech Stack          | Python, Flask, JavaScript, HTML/CSS    |
